# %%
pip3 intall panda
# Out:
#   File "<ipython-input-14-f0e09f945aeb>", line 1
#     pip3 intall panda
#               ^
# SyntaxError: invalid syntax

# %%
pip3 install numpy
# Out:
#   File "<ipython-input-15-0a0fc7a77e37>", line 1
#     pip3 install numpy
#                ^
# SyntaxError: invalid syntax

# %%
pip3 install paho-mqtt
# Out:
#   File "<ipython-input-16-e30b87d456b0>", line 1
#     pip3 install paho-mqtt
#                ^
# SyntaxError: invalid syntax

# %%
pip3 install jupyter
# Out:
#   File "<ipython-input-17-d8a1ee36dadd>", line 1
#     pip3 install jupyter
#                ^
# SyntaxError: invalid syntax

# %%
pip3 install matplotlib
# Out:
#   File "<ipython-input-18-f73546985525>", line 1
#     pip3 install matplotlib
#                ^
# SyntaxError: invalid syntax

# %%
pip3 install xlwt
# Out:
#   File "<ipython-input-19-e747a7e28626>", line 1
#     pip3 install xlwt
#                ^
# SyntaxError: invalid syntax

# %%
pip3 install xlrd
# Out:
#   File "<ipython-input-20-4f9a539017aa>", line 1
#     pip3 install xlrd
#                ^
# SyntaxError: invalid syntax

# %%
from pymongo import MongoClient
import pandas as pd

# %%
#Conectando à base remota no Mongodb do AWS

mongo_client = MongoClient('18.229.104.131', 27017)
mongo_db = mongo_client['inatel']
mongo_collection = mongo_db['in242']

# %%
# Criando o dataframe 

dados = list(mongo_collection.find())
df = pd.DataFrame(dados)

# %%
# Conferência do Dataframe
df.head()
# Out:
#                         _id  temperatura             data_coleta
# 0  5db5c54a406e8f109c7c31ab    29.559199 2019-10-27 13:26:50.333
# 1  5db5c54b406e8f109c7c31ac    27.938756 2019-10-27 13:26:51.335
# 2  5db5c54c406e8f109c7c31ad    26.646084 2019-10-27 13:26:52.337
# 3  5db5c54d406e8f109c7c31ae    19.886545 2019-10-27 13:26:53.340
# 4  5db5c54e406e8f109c7c31af    20.718807 2019-10-27 13:26:54.343

# %%
# Início da Análise do DataFrame
df.count()
# Out:
# _id            6414
# temperatura    6414
# data_coleta    6414
# dtype: int64

# %%
df['temperatura'].max()
# Out:
# 29.997389624063725

# %%
df['temperatura'].min()
# Out:
# 15.00331274058563

# %%
df['temperatura'].mean()
# Out:
# 22.547578763640377

# %%
df.tail()
# Out:
#                            _id  temperatura             data_coleta
# 6409  5db8d2a3d4a1da347d79d53c    27.331868 2019-10-29 21:00:35.654
# 6410  5db8d2a4d4a1da347d79d53d    28.243573 2019-10-29 21:00:36.655
# 6411  5db8d2a5d4a1da347d79d53e    21.405654 2019-10-29 21:00:37.657
# 6412  5db8d2a6d4a1da347d79d53f    23.796107 2019-10-29 21:00:38.658
# 6413  5db8d2a7d4a1da347d79d540    17.948962 2019-10-29 21:00:39.659

# %%
df.median()
# Out:
# temperatura    22.66436
# dtype: float64

# %%
# Criando arquivo do excel
df.to_excel('BaseDeDados.xls')

# %%
# Criando CSV
df.to_csv('BaseDeDados.csv')

# %%
# Uso da função describe- 
df.describe()
# Out:
#        temperatura
# count  6414.000000
# mean     22.547579
# std       4.307099
# min      15.003313
# 25%      18.745340
# 50%      22.664360
# 75%      26.215348
# max      29.997390

# %%
df.tail()
# Out:
#                            _id  temperatura             data_coleta
# 6409  5db8d2a3d4a1da347d79d53c    27.331868 2019-10-29 21:00:35.654
# 6410  5db8d2a4d4a1da347d79d53d    28.243573 2019-10-29 21:00:36.655
# 6411  5db8d2a5d4a1da347d79d53e    21.405654 2019-10-29 21:00:37.657
# 6412  5db8d2a6d4a1da347d79d53f    23.796107 2019-10-29 21:00:38.658
# 6413  5db8d2a7d4a1da347d79d540    17.948962 2019-10-29 21:00:39.659

# %%
# Aplicando tag de análise quente, frio e normal via função.

def check_temperatura(temperatura):
    if temperatura < 20:
        return 'Frio'
    if temperatura < 25:
        return 'Normal'
    return 'Quente'

# %%
df['sensacao'] = df['temperatura'].apply(check_temperatura)

# %%
#Conferindo df

df.head()
# Out:
#                         _id  temperatura             data_coleta sensacao
# 0  5db5c54a406e8f109c7c31ab    29.559199 2019-10-27 13:26:50.333   Quente
# 1  5db5c54b406e8f109c7c31ac    27.938756 2019-10-27 13:26:51.335   Quente
# 2  5db5c54c406e8f109c7c31ad    26.646084 2019-10-27 13:26:52.337   Quente
# 3  5db5c54d406e8f109c7c31ae    19.886545 2019-10-27 13:26:53.340     Frio
# 4  5db5c54e406e8f109c7c31af    20.718807 2019-10-27 13:26:54.343   Normal

# %%
#Contagem de classificação de temperatura - sensação

df.groupby(['sensacao']).count()
# Out:
#            _id  temperatura  data_coleta
# sensacao
# Frio      2098         2098         2098
# Normal    2171         2171         2171
# Quente    2145         2145         2145

# %%
#Criando gráfico de pizza de sensação
import matplotlib.pyplot as plt

# %%
df.sensacao.value_counts(sort=False).plot.pie()
plt.show()

# %%
df_percentual=(df.sensacao.value_counts(sort=False))/df.temperatura.count()

# %%
df_percentual
# Out:
# Normal    0.338478
# Quente    0.334425
# Frio      0.327097
# Name: sensacao, dtype: float64

# %%
# Criando limites de +ou- 2x desvio padrão 
[df['temperatura'].mean() - 2*df['temperatura'].std() ,df['temperatura'].mean() + 2*df['temperatura'].std() ]
# Out:
# [13.933379927912565, 31.16177759936819]

# %%
# Análise de minutos com maior e menor média de temperatura
q1=df.set_index('data_coleta').resample('min').mean()

# %%
q1.loc[q1.idxmin()['temperatura']]
# Out:
# temperatura    20.80521
# Name: 2019-10-29 20:57:00, dtype: float64

# %%
q1.loc[q1.idxmax()['temperatura']]
# Out:
# temperatura    25.281293
# Name: 2019-10-29 20:56:00, dtype: float64

# %%
# Gerar um DF consolidado com media, min e max e hora.
df2 = pd.DataFrame()

# %%
df2 = df.set_index('data_coleta').resample('H')['temperatura'].agg(['mean','min','max'])

# %%
df2
# Out:
#                           mean        min        max
# data_coleta
# 2019-10-27 13:00:00  22.514010  15.003608  29.958189
# 2019-10-27 14:00:00  22.560639  15.003313  29.997390
# 2019-10-27 15:00:00  22.625113  15.033718  29.991601
# 2019-10-27 16:00:00        NaN        NaN        NaN
# 2019-10-27 17:00:00        NaN        NaN        NaN
# 2019-10-27 18:00:00        NaN        NaN        NaN
# 2019-10-27 19:00:00        NaN        NaN        NaN
# 2019-10-27 20:00:00        NaN        NaN        NaN
# 2019-10-27 21:00:00        NaN        NaN        NaN
# 2019-10-27 22:00:00        NaN        NaN        NaN
# 2019-10-27 23:00:00        NaN        NaN        NaN
# 2019-10-28 00:00:00        NaN        NaN        NaN
# 2019-10-28 01:00:00        NaN        NaN        NaN
# 2019-10-28 02:00:00        NaN        NaN        NaN
# 2019-10-28 03:00:00        NaN        NaN        NaN
# 2019-10-28 04:00:00        NaN        NaN        NaN
# ...

# %%
# Removendo horas sem amostras do Dataframe
df3=df2.dropna(how='all')

# %%
#conferindo o novo df criado
df3
# Out:
#                           mean        min        max
# data_coleta
# 2019-10-27 13:00:00  22.514010  15.003608  29.958189
# 2019-10-27 14:00:00  22.560639  15.003313  29.997390
# 2019-10-27 15:00:00  22.625113  15.033718  29.991601
# 2019-10-29 20:00:00  22.088968  15.095667  29.961613
# 2019-10-29 21:00:00  23.235163  16.226169  29.963270

# %%
# Gráfico de barras da Amostra de df3
df3.plot.bar()

# %%
# Criando a organização por média de temperatura descendente- maior para menor
df3_higher = df3.sort_values(by='mean', ascending=False)

# %%
df3_higher
# Out:
#                           mean        min        max
# data_coleta
# 2019-10-29 21:00:00  23.235163  16.226169  29.963270
# 2019-10-27 15:00:00  22.625113  15.033718  29.991601
# 2019-10-27 14:00:00  22.560639  15.003313  29.997390
# 2019-10-27 13:00:00  22.514010  15.003608  29.958189
# 2019-10-29 20:00:00  22.088968  15.095667  29.961613

# %%
# Eliminando dados máximo e mínimo
df3_higher.drop(['min', 'max'], axis=1, inplace=True)

# %%
# Criando gráfico com os horários de maiores médias de temperatura
df3_higher.plot.bar()

# %%
# Alterando atributos dos gráficos 

plt.style.available
plt.style.use('seaborn-dark-palette')
plt.rcParams['figure.figsize'] = (3,2)

# %%
# Criando novo gráfico com cores e tamanho alterados
df3_higher.plot.bar()

# %%
# Adicionando títulos aos gráficos
df3_higher.plot.bar()
plt.title('Media de temperatura') #adicionando o título
plt.xlabel('Hora')
plt.ylabel('Temperatura')
plt.show()

# %%
#Criando gráficos de caixa
df['temperatura'].plot.box (vert=False, whis=0.75)
plt.rcParams['figure.figsize'] = (8,4)

# %%
# Alterando atributos do gráfico
df3_higher.plot.bar(color='black')
plt.xlabel('Hora')
plt.ylim(15, 25)
plt.ylabel('Temperatura')
plt.style.use('fivethirtyeight')

# %%
# Criando histogramas do DataFrame

plt.rcParams['figure.figsize'] = (10,4)
df3.plot.hist(bins=4)

# %%
df.plot.hist(bins=15)

# %%
#Gráfico de densidade e histograma 
import seaborn as sns
sns.distplot(df['temperatura'], hist=True, rug=True);

# %%
# Distribuição anterior do DF não é uma distribuição Normal

# %%
# Criando gráficos de dispersão

scatter_plot = plt.scatter(df['data_coleta'], df['temperatura'], alpha=0.1, 
                           c=df['temperatura'])
plt.show()
plt.rcParams['figure.figsize'] = (3,10)

# %%
#Alterando atributos do gráfico de dispersão

scatter_plot = plt.scatter(df['temperatura'], df['data_coleta'], alpha=0.1, 
                           c=df['temperatura'])
plt.xlabel('temperatura')
plt.ylabel('data_coleta')
plt.ylim('2019-10-27 13:00','2019-10-27 15:30')
plt.xlim(14, 31)
plt.rcParams['figure.figsize'] = (14,6)

# %%
# Importando CSV
DF_CSV = pd.read_csv("BaseDeDados.csv")

# %%
#Usando a biblioteca 'statistics'
import statistics
statistics.mean(DF_CSV['temperatura'])
# Out:
# 22.54757876364041

# %%
statistics.median(DF_CSV['temperatura'])
# Out:
# 22.664359851530293

# %%
statistics.median_low(DF_CSV['temperatura'])
# Out:
# 22.66427831826837

# %%
statistics.median_high(DF_CSV['temperatura'])
# Out:
# 22.66444138479222

# %%
statistics.median_grouped(DF_CSV['temperatura'])
# Out:
# 22.16444138479222

# %%
statistics.variance(DF_CSV['temperatura'])
# Out:
# 18.551105395363614

# %%
statistics.pvariance(DF_CSV['temperatura'])
# Out:
# 18.548213112015414

# %%
statistics.stdev(DF_CSV['temperatura'])
# Out:
# 4.307099417863908

# %%
statistics.pstdev(DF_CSV['temperatura'])
# Out:
# 4.306763647103868

# %%
#Comparando as bases df e DF_CSV
df.describe()
# Out:
#        temperatura
# count  6414.000000
# mean     22.547579
# std       4.307099
# min      15.003313
# 25%      18.745340
# 50%      22.664360
# 75%      26.215348
# max      29.997390

# %%
DF_CSV.describe()
# Out:
#         Unnamed: 0  temperatura
# count  6414.000000  6414.000000
# mean   3206.500000    22.547579
# std    1851.706645     4.307099
# min       0.000000    15.003313
# 25%    1603.250000    18.745340
# 50%    3206.500000    22.664360
# 75%    4809.750000    26.215348
# max    6413.000000    29.997390
